# %%
import hail as hl
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d5e533bd-e8d4-49be-a4eb-b5b36af55f43">Loading BokehJS ...</span>
#     </div>

# %%
hl.init()
# Out:
# /opt/anaconda3/envs/hail/lib/python3.9/site-packages/hail/backend/service_backend.py:563: UserWarning:
#
# Modifying the requester pays project or buckets at runtime using flags is deprecated. Expect this behavior to become unsupported soon.
#
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.133-4c60fddb171a
# LOGGING: writing to /Users/tk508/Work/GenGym/genetics-gym-final/data_preprocessing/VSMs/hail-20260212-1104-0.2.133-4c60fddb171a.log

# %%
import pandas as pd

# %%
df = pd.read_csv("gs://genetics-gym/linkers/linker_missense_only_snp.tsv.gz", sep="\t", compression="gzip", index_col=['chr', 'pos', 'ref', 'alt'])

# %%
df.index
# Out:
# MultiIndex([('chr1', 65568, 'A', 'C'),
#             ('chr1', 65568, 'A', 'G'),
#             ('chr1', 65569, 'A', 'C'),
#             ('chr1', 65569, 'A', 'G'),
#             ('chr1', 65569, 'A', 'T'),
#             ('chr1', 65570, 'G', 'C'),
#             ('chr1', 65570, 'G', 'T'),
#             ('chr1', 65571, 'A', 'C'),
#             ('chr1', 65571, 'A', 'G'),
#             ('chr1', 65572, 'A', 'C'),
#             ('chr1', 65572, 'A', 'G'),
#             ('chr1', 65572, 'A', 'T'),
#             ('chr1', 65573, 'G', 'C'),
#             ('chr1', 65573, 'G', 'T'),
#             ('chr1', 69037, 'G', 'A'),
#             ('chr1', 69037, 'G', 'C'),
#             ('chr1', 69037, 'G', 'T'),
#             ('chr1', 69038, 'T', 'A'),
#             ('chr1', 69038, 'T', 'C'),
#             ('chr1', 69038, 'T', 'G'),
#             ('chr1', 69040, 'A', 'C'),
#             ('chr1', 69040, 'A', 'G'),
#             ('chr1', 69040, 'A', 'T'),
#             ('chr1', 69041, 'C', 'A'),
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# ...
